# %% [markdown]
# <a href="https://colab.research.google.com/github/JABU-2022/Product-Clustering-for-Enhanced-Marketing/blob/main/Product_Clustering_Synergix_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem statement**

# %% [markdown]
# Synergix Solutions has found that its marketing strategies based on existing segments are not very effective. They want to try out new-age bundled online marketing strategies, which will require them to group similar products irrespective of the segments

# %% [markdown]
# # **To solve this problem we will use K-means**

# %% [markdown]
#  **To perform clustering using K-means we will follow the following steps**

# %% [markdown]
# 1. **Load the dataset:** Uploading the dataset into the notebook environment
#
# 2. **Feature selection:** Choose features from the dataset that are relevant for the problem statement
#
# 3. **Pre-process the data:**Use relevant preprocessing measures for the problem statement
#
# 4. **Apply K-means clustering:** Use the K-means alograthim to cluster the data based on the different number of clusters
#
# 5. **Find the Optimal K:**Find the optimal number of clusters using different methods and run the K-means algorithm with the desired numbers of clusters.
#
# 6. **Evaluate and interpret the clusters:** Analyse and interpret the clusters by plotting different features with cluster labels

# %% [markdown]
# # **IMPORT THE NECESSARY LIBRARIES**

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# **Step 1: Load the dataset**

# %%
data_preprocessed = pd.read_csv("data_preprocessed.csv")
df = data_preprocessed.head()
df.head()
# Out:
#     SKU_ID        Date  Page_traffic  Revenue($)  Unit_price  Units_sold  \
# 0  SKU1539  2022-04-09        5835.0       46006   22.214389        2071
# 1  SKU1431  2021-05-08        1881.0        8084   11.870778         681
# 2   SKU995  2022-12-24        2477.0       24190   27.645714         875
# 3  SKU1136  2022-10-08        4087.0       23588   16.896848        1396
# 4   SKU528  2022-03-26        1446.0       13446   16.357664         822
#
#      Segment  1_Star_Rating  2_Star_Rating  3_Star_Rating  ...  Sum of Spend  \
# 0   Skincare           99.0           72.0          194.0  ...           0.0
# 1   Skincare          118.0           73.0          200.0  ...           0.0
# 2     Makeup          108.0           85.0          232.0  ...           0.0
# 3     Makeup           82.0           64.0          167.0  ...           0.0
# 4  Hair Care           29.0           24.0           88.0  ...           0.0
#
# ...

# %% [markdown]
# **Step 2: Processing and feature selection for clustering**

# %%
df.sort_values(by=['SKU_ID', 'Date'], inplace=True)
df
# Out:
# <ipython-input-11-ed9cc9d5164a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['SKU_ID', 'Date'], inplace=True)
#     SKU_ID        Date  Page_traffic  Revenue($)  Unit_price  Units_sold  \
# 3  SKU1136  2022-10-08        4087.0       23588   16.896848        1396
# 1  SKU1431  2021-05-08        1881.0        8084   11.870778         681
# 0  SKU1539  2022-04-09        5835.0       46006   22.214389        2071
# 4   SKU528  2022-03-26        1446.0       13446   16.357664         822
# 2   SKU995  2022-12-24        2477.0       24190   27.645714         875
#
#      Segment  1_Star_Rating  2_Star_Rating  3_Star_Rating  ...  Sum of Spend  \
# 3     Makeup           82.0           64.0          167.0  ...           0.0
# ...

# %%
df.columns.tolist()
# Out:
# ['SKU_ID',
#  'Date',
#  'Page_traffic',
#  'Revenue($)',
#  'Unit_price',
#  'Units_sold',
#  'Segment',
#  '1_Star_Rating',
#  '2_Star_Rating',
#  '3_Star_Rating',
#  '4_Star_Rating',
#  '5_Star_Rating',
#  'Image_Count',
#  'Bullet_Count',
#  'Title_Count',
#  'Description_Length',
#  'num_unique_Search_Terms',
#  'Organic Search Rank',
#  'Num_of_Promotions',
#  'Sum of Spend',
#  'Online_Clicks',
#  'Online_Cost',
#  'Online_Impressions',
#  'num_unique_campaigns',
#  'Clicks_video',
#  'Cost_video',
#  'Impressions_video',
#  'num_unique_campaigns_offline',
#  'Units_sold>1000']
